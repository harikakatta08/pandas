# %% [markdown]
# <a href="https://colab.research.google.com/github/harikakatta08/pandas/blob/main/student%20perfomance%20analysis%20mini%20project%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = {
    "Name": ["Harika","Anil","Sneha","Ravi","Divya","Kiran","Pooja","Arjun","Meena","Rahul",
             "Suresh","Lakshmi","Vikram","Nisha","Teja","Akhil","Swathi","Manoj","Keerthi","Ramesh"],
    "Maths": [85,45,88,30,72,95,55,60,78,50,67,92,38,81,58,69,87,46,73,62],
    "Science": [78,56,90,40,68,89,65,62,82,45,70,94,42,76,60,72,91,50,77,58],
    "English": [92,60,84,35,75,91,58,64,79,55,65,90,40,85,57,70,88,48,80,61],
    "Attendance": [90,70,95,60,85,98,75,80,88,72,83,97,68,89,74,82,93,71,86,78]
}

df = pd.DataFrame(data)

print(" Original Student Dataset:")
display(df)


df["Total"] = df["Maths"] + df["Science"] + df["English"]
df["Average"] = df["Total"] / 3


df["Result"] = df["Average"].apply(lambda x: "Pass" if x >= 40 else "Fail")

print("\n Updated Dataset with Total, Average, Result:")
display(df)


topper = df.loc[df["Total"].idxmax()]
print("\n Top Performer Details:")
display(topper)


subject_avg = df[["Maths", "Science", "English"]].mean()
print("\n Subject-wise Average Marks:")
display(subject_avg)

high_att = df[df["Attendance"] > 85]
print("\n Students with High Attendance (>85):")
display(high_att[["Name", "Attendance", "Average"]])


plt.figure()
subject_avg.plot(kind="bar")
plt.title("Subject Wise Average Marks")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.show()


result_counts = df["Result"].value_counts()
plt.figure()
result_counts.plot(kind="pie", autopct="%1.1f%%")
plt.title("Pass vs Fail Distribution")
plt.ylabel("")
plt.show()


plt.figure()
plt.scatter(df["Attendance"], df["Average"])
plt.title("Attendance vs Average Marks")
plt.xlabel("Attendance")
plt.ylabel("Average Marks")
plt.show()


df.to_csv("processed_students.csv", index=False)

from google.colab import files
files.download("processed_students.csv")

print("\n Project Completed Successfully!")
# Out:
#  Original Student Dataset:
#        Name  Maths  Science  English  Attendance
# 0    Harika     85       78       92          90
# 1      Anil     45       56       60          70
# 2     Sneha     88       90       84          95
# 3      Ravi     30       40       35          60
# 4     Divya     72       68       75          85
# 5     Kiran     95       89       91          98
# 6     Pooja     55       65       58          75
# 7     Arjun     60       62       64          80
# 8     Meena     78       82       79          88
# 9     Rahul     50       45       55          72
# 10   Suresh     67       70       65          83
# 11  Lakshmi     92       94       90          97
# 12   Vikram     38       42       40          68
# 13    Nisha     81       76       85          89
# 14     Teja     58       60       57          74
# 15    Akhil     69       72       70          82
# 16   Swathi     87       91       88          93
# 17    Manoj     46       50       48          71
# ...
